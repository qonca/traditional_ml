# %% [markdown]
# <a href="https://colab.research.google.com/github/qonca/traditional_ml/blob/main/turbo_az.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !kaggle datasets download sehriyarmemmedli/turboaz-cars-project
# !unzip turboaz-cars-project.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sehriyarmemmedli/turboaz-cars-project
# License(s): unknown
# ...
#  99% 237M/240M [00:03<00:00, 54.1MB/s]
# 100% 240M/240M [00:03<00:00, 71.6MB/s]
# Archive:  turboaz-cars-project.zip
#   inflating: cars.csv

# %%
import pandas as pd
df = pd.read_csv('/content/cars.csv')

# %%
df
# Out:
#                                         id_x  \
# 0       3c234145-d57a-4ad6-9448-d43810fc3392
# 1       c74ea36f-6be1-4de4-926d-e117197dcf00
# 2       9cefceb0-024d-4581-a869-a3c2c68a9f95
# 3       459cc337-fb63-48de-9694-41554923d311
# 4       6c5ee8d8-1c6f-4fad-a694-957a4c43c25d
# ...                                      ...
# 653716  16caa803-a546-455b-81ff-bc20868c2136
# 653717  2a26a6c1-8914-4b68-abb4-1fbd12ced7bc
# 653718  feb75615-0131-4d6f-b009-cc02faea4e01
# 653719  e5f8e957-5543-42be-b30f-78723ce551f9
# 653720  a59362fe-117b-4b1c-bd43-636f1469cdbb
#
#                               car_rel_url_x                datetime_scrape  \
# 0                /autos/8748840-hyundai-i30  2024-09-13 20:32:19.751157+00
# 1       /autos/8475807-lada-vaz-niva-travel  2024-09-13 20:32:19.751157+00
# 2        /autos/8739686-toyota-land-cruiser  2024-09-13 20:32:19.751157+00
# 3            /autos/8712597-hyundai-elantra  2024-09-13 20:32:19.751157+00
# ...

# %%
df['new_currency'] = 0

# %%
def currency_converter(currency):
    if currency == 'AZN':
        return 1
    elif currency == '$':
        return 1.7
    else:
        return 1.76


df['new_currency'] = df['currency_x'].apply(currency_converter)

# %%
c = currency_converter(df['currency_x'][0])
c
# Out:
# 1

# %%
df['real_price'] = df['new_currency']*df['price_x']

# %%
df['real_price']
# Out:
# 0          15000.0
# 1          23700.0
# 2          60520.0
# 3          26700.0
# 4          10500.0
#             ...
# 653716     10800.0
# 653717      9500.0
# 653718     25400.0
# 653719     10600.0
# 653720    218450.0
# Name: real_price, Length: 653721, dtype: float64

# %%
rows, columns = df.shape
df_copy = df.copy

# %%
import matplotlib.pyplot as plt
df[:1000].plot(kind = 'bar', x = 'vip', y = 'price_x');

# %%
df.columns
# Out:
# Index(['id_x', 'car_rel_url_x', 'datetime_scrape', 'name', 'price_x',
#        'currency_x', 'datetime_product', 'city', 'day', 'hour', 'attributes',
#        'production_year', 'engine_displacement_num',
#        'engine_displacement_unit', 'kilometrage_num', 'kilometrage_unit',
#        'barter', 'loan', 'salon', 'spare_parts', 'vip', 'featured', 'img_url',
#        'id_y', 'cars_id', 'car_rel_url_y', 'datetime', 'description',
#        'price_y', 'currency_y', 'owner_name', 'shop_name', 'phone', 'updated',
#        'views', 'vin', 'car_details_id_x', 'Ban növü', 'Buraxılış ili',
#        'Hansı bazar üçün yığılıb', 'Marka', 'Model', 'Mühərrik', 'Qəzalı',
#        'Rəng', 'Sahiblər', 'Sürətlər qutusu', 'Vəziyyəti', 'Yeni',
#        'Yerlərin sayı', 'Yürüş', 'Ötürücü', 'Şəhər', 'car_details_id_y',
#        'car_rel_url', 'extra_info', 'new_currency', 'real_price'],
#       dtype='object')

# %%
df['Ban növü']
# Out:
# 0                 Hetçbek, 5 qapı
# 1         Offroader / SUV, 5 qapı
# 2         Offroader / SUV, 5 qapı
# 3                           Sedan
# 4                         Liftbek
#                    ...
# 653716                    Liftbek
# 653717    Offroader / SUV, 5 qapı
# 653718                      Sedan
# 653719    Offroader / SUV, 5 qapı
# 653720    Offroader / SUV, 5 qapı
# Name: Ban növü, Length: 653721, dtype: object

# %%
df[['type','door']] = df['Ban növü'].str.split(',', expand = True)

# %%
df['door'].isna().sum()
# Out:
# 354366

# %%
df.groupby(['type'])['type'].count()
# Out:
# type
# Avtobus               312
# Dartqı               2599
# Fastbek                 3
# Fayton                  1
# Furqon              16803
# Hetçbek             44515
# Kabriolet             533
# Karvan                 13
# Kompakt-Van          3437
# Kupe                 3743
# Kvadrosikl             99
# Liftbek             22629
# Limuzin                21
# Mikroavtobus         1418
# Mikrovan               11
# Minivan             10056
# Moped                 194
# Motosiklet           1914
# Offroader / SUV    231618
# Pikap                4868
# Qolfkar                 1
# Rodster               284
# SUV Kupe             4451
# Sedan              277955
# Spidster                2
# Tarqa                   2
# Universal           18354
# Van                    50
# Yük maşını           7835
# Name: type, dtype: int64

# %%
df.groupby(['door'])['door'].count()
# Out:
# door
# 3 qapı               7404
# 4 qapı                436
# 5 qapı             286457
# açıq                  190
# bir yarım kabin        29
# ikiqat kabin         4785
# tək kabin              54
# Name: door, dtype: int64

# %%
df.groupby(['engine_displacement_num'])['engine_displacement_num'].count()
# Out:
# engine_displacement_num
# 0.0      16731
# 0.1        316
# 0.2        533
# 0.3        171
# 0.4        176
#          ...
# 16.0        25
# 19.0         1
# 20.0        19
# 22.0         1
# 120.0       11
# Name: engine_displacement_num, Length: 88, dtype: int64

# %%
df['Qəzalı'] = df['Qəzalı'].fillna('Xeyr')

# %%
df.groupby(['Qəzalı'])['Qəzalı'].count()
# Out:
# Qəzalı
# Bəli      1761
# Xeyr    651960
# Name: Qəzalı, dtype: int64

# %%
df['Vəziyyəti'].isna().sum()
# Out:
# 3

# %%
df[['Mühərrik','Qəzalı','Vəziyyəti']]
# Out:
#                          Mühərrik Qəzalı                    Vəziyyəti
# 0            1.6 L/115 a.g./Dizel   Xeyr  Vuruğu yoxdur, rənglənməyib
# 1            1.7 L/80 a.g./Benzin   Xeyr  Vuruğu yoxdur, rənglənməyib
# 2           4.0 L/282 a.g./Benzin   Xeyr  Vuruğu yoxdur, rənglənməyib
# 3           2.0 L/150 a.g./Benzin   Xeyr  Vuruğu yoxdur, rənglənməyib
# 4            1.5 L/76 a.g./Hibrid   Xeyr  Vuruğu yoxdur, rənglənməyib
# ...                           ...    ...                          ...
# 653716   1.5 L / 76 a.g. / Hibrid   Xeyr  Vuruğu yoxdur, rənglənməyib
# 653717  2.9 L / 135 a.g. / Benzin   Xeyr  Vuruğu yoxdur, rənglənməyib
# 653718  2.0 L / 150 a.g. / Benzin   Xeyr  Vuruğu yoxdur, rənglənməyib
# 653719  4.7 L / 258 a.g. / Benzin   Xeyr  Vuruğu yoxdur, rənglənməyib
# 653720  3.0 L / 400 a.g. / Benzin   Xeyr  Vuruğu yoxdur, rənglənməyib
#
# [653721 rows x 3 columns]

# %%
df[['State', 'Colored']] = df['Vəziyyəti'].str.split(",", expand = True)

# %%
df[['State', 'Colored']]
# Out:
#                 State        Colored
# 0       Vuruğu yoxdur   rənglənməyib
# 1       Vuruğu yoxdur   rənglənməyib
# 2       Vuruğu yoxdur   rənglənməyib
# 3       Vuruğu yoxdur   rənglənməyib
# 4       Vuruğu yoxdur   rənglənməyib
# ...               ...            ...
# 653716  Vuruğu yoxdur   rənglənməyib
# 653717  Vuruğu yoxdur   rənglənməyib
# 653718  Vuruğu yoxdur   rənglənməyib
# 653719  Vuruğu yoxdur   rənglənməyib
# 653720  Vuruğu yoxdur   rənglənməyib
#
# [653721 rows x 2 columns]

# %%
df.groupby(['State'])['State'].count()
# Out:
# State
# Vuruğu var         6458
# Vuruğu yoxdur    647260
# Name: State, dtype: int64

# %%
df.groupby('Mühərrik')['Mühərrik'].count()
# Out:
# Mühərrik
# 0.0 L / 6 a.g. / Benzin     1
# 0.0 L/10 a.g./Benzin        1
# 0.0 L/1020 a.g./Elektro     5
# 0.0 L/109 a.g./Elektro     82
# 0.0 L/111 a.g./Elektro      1
#                            ..
# 9.7 L/430 a.g./Dizel        4
# 900 sm                     27
# 94 a.g. / Elektro          38
# 95 a.g. / Elektro          37
# 966 a.g. / Elektro          1
# Name: Mühərrik, Length: 7410, dtype: int64

# %%
df['kilometrage_num']
# Out:
# 0         270000
# 1              0
# 2         164750
# 3         126000
# 4         354000
#            ...
# 653716    320000
# 653717    155000
# 653718     77926
# 653719    250000
# 653720     19000
# Name: kilometrage_num, Length: 653721, dtype: int64

# %%
df['description']
# Out:
# 0         Salam orjinal probeqdir bir ildi bizdedir biri...
# 1         LADA Niva Travel modelini nəğd və ya sərfəli l...
# 2         Bezkraska.Mashinda hec bir problem yoxdur.Alve...
# 3                                               2019 alış\n
# 4         Maşında problem yoxdur. Motor, ABS və batareya...
#                                 ...
# 653716    Maşın yaxşı vəziyətdədir heç bir prablemi yoxd...
# 653717    2012 alış. İdeal vəziyyətdədir. Udar vuruğu yo...
# 653718    Amerikadan yeni gelib. Tex passport 2018. 2 sa...
# 653719    Təcili Satılır  real alıcıya endirim olacaq be...
# 653720    Defender X\n160000€ ya alinib \nHech bir detal...
# Name: description, Length: 653721, dtype: object

# %%
df['spare_parts'].isna().sum()
# Out:
# 651959

# %%
df[['year','size_eng', 'kmg']] = df['attributes'].str.split(',', expand = True)

# %%
df['Ötürücü'].isna().sum()
# Out:
# 0

# %%
df['Mühərrik']
# Out:
# 0              1.6 L/115 a.g./Dizel
# 1              1.7 L/80 a.g./Benzin
# 2             4.0 L/282 a.g./Benzin
# 3             2.0 L/150 a.g./Benzin
# 4              1.5 L/76 a.g./Hibrid
#                     ...
# 653716     1.5 L / 76 a.g. / Hibrid
# 653717    2.9 L / 135 a.g. / Benzin
# 653718    2.0 L / 150 a.g. / Benzin
# 653719    4.7 L / 258 a.g. / Benzin
# 653720    3.0 L / 400 a.g. / Benzin
# Name: Mühərrik, Length: 653721, dtype: object

# %%
df[['size_eng','production_year','Colored', 'State','Sürətlər qutusu','Marka', 'Model', 'Yeni', 'Yürüş', 'Ötürücü', 'door','type']]
# Out:
#        size_eng  production_year        Colored          State  \
# 0         1.6 L             2008   rənglənməyib  Vuruğu yoxdur
# 1         1.7 L             2024   rənglənməyib  Vuruğu yoxdur
# 2         4.0 L             2011   rənglənməyib  Vuruğu yoxdur
# 3         2.0 L             2018   rənglənməyib  Vuruğu yoxdur
# 4         1.5 L             2007   rənglənməyib  Vuruğu yoxdur
# ...         ...              ...            ...            ...
# 653716    1.5 L             2008   rənglənməyib  Vuruğu yoxdur
# 653717    2.9 L             2011   rənglənməyib  Vuruğu yoxdur
# 653718    2.0 L             2018   rənglənməyib  Vuruğu yoxdur
# 653719    4.7 L             1999   rənglənməyib  Vuruğu yoxdur
# 653720    3.0 L             2023   rənglənməyib  Vuruğu yoxdur
#
#        Sürətlər qutusu       Marka           Model  Yeni       Yürüş Ötürücü  \
# 0             Mexaniki     Hyundai             i30  Xeyr  270 000 km      Ön
# ...

# %%
df[['eng_size', 'horse_power', 'eng_type']] = df['Mühərrik'].str.split('/', expand = True)

# %%
df['horse_power'].isna().sum()
# Out:
# 344

# %%
df['horse_power']
# Out:
# 0           115 a.g.
# 1            80 a.g.
# 2           282 a.g.
# 3           150 a.g.
# 4            76 a.g.
#              ...
# 653716      76 a.g.
# 653717     135 a.g.
# 653718     150 a.g.
# 653719     258 a.g.
# 653720     400 a.g.
# Name: horse_power, Length: 653721, dtype: object

# %%
df['barter'].isna().sum()
# Out:
# 428168

# %%
df['kilometrage_unit'].nunique()
# Out:
# 1

# %%
df
# Out:
#                                         id_x  \
# 0       3c234145-d57a-4ad6-9448-d43810fc3392
# 1       c74ea36f-6be1-4de4-926d-e117197dcf00
# 2       9cefceb0-024d-4581-a869-a3c2c68a9f95
# 3       459cc337-fb63-48de-9694-41554923d311
# 4       6c5ee8d8-1c6f-4fad-a694-957a4c43c25d
# ...                                      ...
# 653716  16caa803-a546-455b-81ff-bc20868c2136
# 653717  2a26a6c1-8914-4b68-abb4-1fbd12ced7bc
# 653718  feb75615-0131-4d6f-b009-cc02faea4e01
# 653719  e5f8e957-5543-42be-b30f-78723ce551f9
# 653720  a59362fe-117b-4b1c-bd43-636f1469cdbb
#
#                               car_rel_url_x                datetime_scrape  \
# 0                /autos/8748840-hyundai-i30  2024-09-13 20:32:19.751157+00
# 1       /autos/8475807-lada-vaz-niva-travel  2024-09-13 20:32:19.751157+00
# 2        /autos/8739686-toyota-land-cruiser  2024-09-13 20:32:19.751157+00
# 3            /autos/8712597-hyundai-elantra  2024-09-13 20:32:19.751157+00
# ...

# %%
df.drop(columns = ['id_x','car_rel_url_x','datetime_scrape','price_x','currency_x', 'datetime_product','city','day','hour','attributes','engine_displacement_unit','kilometrage_unit','eng_size'],inplace= True)

# %%
df
# Out:
#                           name  production_year  engine_displacement_num  \
# 0                  Hyundai i30             2008                      1.6
# 1       LADA (VAZ) Niva Travel             2024                      1.7
# 2          Toyota Land Cruiser             2011                      4.0
# 3              Hyundai Elantra             2018                      2.0
# 4                 Toyota Prius             2007                      1.5
# ...                        ...              ...                      ...
# 653716            Toyota Prius             2008                      1.5
# 653717              UAZ Hunter             2011                      2.9
# 653718         Hyundai Elantra             2018                      2.0
# 653719     Jeep Grand Cherokee             1999                      4.7
# 653720     Land Rover Defender             2023                      3.0
#
#         kilometrage_num            barter loan  salon spare_parts  \
# ...

# %%
df.drop(columns = ['production_year', 'kmg'], inplace =True)

# %%
df['vin']
# Out:
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3         5NPD84LFXKH406133
# 4                       NaN
#                 ...
# 653716                  NaN
# 653717                  NaN
# 653718    5NPD84LF9JH337806
# 653719                  NaN
# 653720                  NaN
# Name: vin, Length: 653721, dtype: object

# %%
df.drop(columns = ['price_y', 'currency_y','shop_name', 'phone','Şəhər'], inplace = True)

# %%
df
# Out:
#                           name  engine_displacement_num  kilometrage_num  \
# 0                  Hyundai i30                      1.6           270000
# 1       LADA (VAZ) Niva Travel                      1.7                0
# 2          Toyota Land Cruiser                      4.0           164750
# 3              Hyundai Elantra                      2.0           126000
# 4                 Toyota Prius                      1.5           354000
# ...                        ...                      ...              ...
# 653716            Toyota Prius                      1.5           320000
# 653717              UAZ Hunter                      2.9           155000
# 653718         Hyundai Elantra                      2.0            77926
# 653719     Jeep Grand Cherokee                      4.7           250000
# 653720     Land Rover Defender                      3.0            19000
#
#                   barter loan  salon spare_parts          vip       featured  \
# ...

# %%
df['Mühərrik']
# Out:
# 0              1.6 L/115 a.g./Dizel
# 1              1.7 L/80 a.g./Benzin
# 2             4.0 L/282 a.g./Benzin
# 3             2.0 L/150 a.g./Benzin
# 4              1.5 L/76 a.g./Hibrid
#                     ...
# 653716     1.5 L / 76 a.g. / Hibrid
# 653717    2.9 L / 135 a.g. / Benzin
# 653718    2.0 L / 150 a.g. / Benzin
# 653719    4.7 L / 258 a.g. / Benzin
# 653720    3.0 L / 400 a.g. / Benzin
# Name: Mühərrik, Length: 653721, dtype: object

# %%
df['featured'].unique()
# Out:
# array([nan, 'featured-icon'], dtype=object)

# %%
df['car_rel_url']
# Out:
# 0                  /autos/8748840-hyundai-i30
# 1         /autos/8475807-lada-vaz-niva-travel
# 2          /autos/8739686-toyota-land-cruiser
# 3              /autos/8712597-hyundai-elantra
# 4                 /autos/8674773-toyota-prius
#                          ...
# 653716            /autos/9081944-toyota-prius
# 653717              /autos/9081939-uaz-hunter
# 653718         /autos/9055034-hyundai-elantra
# 653719     /autos/9065903-jeep-grand-cherokee
# 653720     /autos/9077844-land-rover-defender
# Name: car_rel_url, Length: 653721, dtype: object

# %%
df.columns
# Out:
# Index(['name', 'engine_displacement_num', 'kilometrage_num', 'barter', 'loan',
#        'salon', 'spare_parts', 'vip', 'featured', 'img_url', 'id_y', 'cars_id',
#        'car_rel_url_y', 'datetime', 'description', 'owner_name', 'updated',
#        'views', 'vin', 'car_details_id_x', 'Ban növü', 'Buraxılış ili',
#        'Hansı bazar üçün yığılıb', 'Marka', 'Model', 'Mühərrik', 'Qəzalı',
#        'Rəng', 'Sahiblər', 'Sürətlər qutusu', 'Vəziyyəti', 'Yeni',
#        'Yerlərin sayı', 'Yürüş', 'Ötürücü', 'car_details_id_y', 'car_rel_url',
#        'extra_info', 'new_currency', 'real_price', 'type', 'door', 'State',
#        'Colored', 'year', 'size_eng', 'horse_power', 'eng_type'],
#       dtype='object')

# %%
df['car_details_id_x']
# Out:
# 0         8d84d800-fafd-4d5c-b640-f47bd6c5ac20
# 1         2cf8b84b-adaf-467a-8f06-3dabcf866c8a
# 2         22bb3704-ebe7-4357-ba2f-1806d1a7042b
# 3         e0d16dac-4091-4417-916e-cadeff600f95
# 4         82078856-0d07-4a0d-8123-69c2e5002e07
#                           ...
# 653716    15770ce6-f9db-411e-baeb-5ca6e525e1eb
# 653717    e73e0e76-a139-404e-bf43-875e16799544
# 653718    b7758882-a169-4351-9a14-a3692d9ee9c9
# 653719    37020736-2c34-4b02-b7f7-62e81cb72bb8
# 653720    11845ef9-cc32-4df6-8910-f862a068ffb5
# Name: car_details_id_x, Length: 653721, dtype: object

# %%
df['Hansı bazar üçün yığılıb'].isna().sum()
# Out:
# 189505

# %%
df.drop(columns = ['car_details_id_y','car_rel_url','size_eng','extra_info','Sahiblər','car_details_id_x','car_rel_url_y','cars_id'], inplace = True)

# %%
df
# Out:
#                           name  engine_displacement_num  kilometrage_num  \
# 0                  Hyundai i30                      1.6           270000
# 1       LADA (VAZ) Niva Travel                      1.7                0
# 2          Toyota Land Cruiser                      4.0           164750
# 3              Hyundai Elantra                      2.0           126000
# 4                 Toyota Prius                      1.5           354000
# ...                        ...                      ...              ...
# 653716            Toyota Prius                      1.5           320000
# 653717              UAZ Hunter                      2.9           155000
# 653718         Hyundai Elantra                      2.0            77926
# 653719     Jeep Grand Cherokee                      4.7           250000
# 653720     Land Rover Defender                      3.0            19000
#
#                   barter loan  salon spare_parts          vip       featured  \
# ...

# %%
df['datetime']
# Out:
# 0         2024-09-13 20:40:28.618345+00
# 1         2024-09-13 20:40:28.618345+00
# 2         2024-09-13 20:40:28.618345+00
# 3         2024-09-13 20:40:28.618345+00
# 4         2024-09-13 20:40:28.618345+00
#                       ...
# 653716       2025-01-05 20:23:28.915653
# 653717       2025-01-05 20:23:28.915653
# 653718       2025-01-05 20:23:28.915653
# 653719       2025-01-05 20:23:28.915653
# 653720       2025-01-05 20:23:28.915653
# Name: datetime, Length: 653721, dtype: object

# %%
df.columns
# Out:
# Index(['name', 'engine_displacement_num', 'kilometrage_num', 'barter', 'loan',
#        'salon', 'spare_parts', 'vip', 'featured', 'img_url', 'id_y',
#        'datetime', 'description', 'owner_name', 'updated', 'views', 'vin',
#        'Ban növü', 'Buraxılış ili', 'Hansı bazar üçün yığılıb', 'Marka',
#        'Model', 'Mühərrik', 'Qəzalı', 'Rəng', 'Sürətlər qutusu', 'Vəziyyəti',
#        'Yeni', 'Yerlərin sayı', 'Yürüş', 'Ötürücü', 'new_currency',
#        'real_price', 'type', 'door', 'State', 'Colored', 'year', 'horse_power',
#        'eng_type'],
#       dtype='object')

# %%
df.drop(columns = ['img_url','id_y','datetime','description','owner_name','updated','views','Mühərrik','Vəziyyəti'], inplace = True)

# %%
df.columns
# Out:
# Index(['name', 'engine_displacement_num', 'kilometrage_num', 'barter', 'loan',
#        'salon', 'spare_parts', 'vip', 'featured', 'vin', 'Ban növü',
#        'Buraxılış ili', 'Hansı bazar üçün yığılıb', 'Marka', 'Model', 'Qəzalı',
#        'Rəng', 'Sürətlər qutusu', 'Yeni', 'Yerlərin sayı', 'Yürüş', 'Ötürücü',
#        'new_currency', 'real_price', 'type', 'door', 'State', 'Colored',
#        'year', 'horse_power', 'eng_type'],
#       dtype='object')

# %%
df['year']
# Out:
# 0         2008
# 1         2024
# 2         2011
# 3         2018
# 4         2007
#           ...
# 653716    2008
# 653717    2011
# 653718    2018
# 653719    1999
# 653720    2023
# Name: year, Length: 653721, dtype: object

# %%
df['Buraxılış ili']
# Out:
# 0         2008
# 1         2024
# 2         2011
# 3         2018
# 4         2007
#           ...
# 653716    2008
# 653717    2011
# 653718    2018
# 653719    1999
# 653720    2023
# Name: Buraxılış ili, Length: 653721, dtype: int64

# %%
df['Ban növü']
# Out:
# 0                 Hetçbek, 5 qapı
# 1         Offroader / SUV, 5 qapı
# 2         Offroader / SUV, 5 qapı
# 3                           Sedan
# 4                         Liftbek
#                    ...
# 653716                    Liftbek
# 653717    Offroader / SUV, 5 qapı
# 653718                      Sedan
# 653719    Offroader / SUV, 5 qapı
# 653720    Offroader / SUV, 5 qapı
# Name: Ban növü, Length: 653721, dtype: object

# %%
df.drop(columns = ['vip', 'featured', 'vin','Ban növü','Buraxılış ili'], inplace = True)

# %%
df
# Out:
#                           name  engine_displacement_num  kilometrage_num  \
# 0                  Hyundai i30                      1.6           270000
# 1       LADA (VAZ) Niva Travel                      1.7                0
# 2          Toyota Land Cruiser                      4.0           164750
# 3              Hyundai Elantra                      2.0           126000
# 4                 Toyota Prius                      1.5           354000
# ...                        ...                      ...              ...
# 653716            Toyota Prius                      1.5           320000
# 653717              UAZ Hunter                      2.9           155000
# 653718         Hyundai Elantra                      2.0            77926
# 653719     Jeep Grand Cherokee                      4.7           250000
# 653720     Land Rover Defender                      3.0            19000
#
#                   barter loan  salon spare_parts Hansı bazar üçün yığılıb  \
# ...

# %%
df.drop(columns = ['name','Yürüş','spare_parts'], inplace = True)

# %%
df['State'].isna().sum()
# Out:
# 3

# %%
df.columns
# Out:
# Index(['engine_displacement_num', 'kilometrage_num', 'barter', 'loan', 'salon',
#        'Hansı bazar üçün yığılıb', 'Marka', 'Model', 'Qəzalı', 'Rəng',
#        'Sürətlər qutusu', 'Yeni', 'Yerlərin sayı', 'Ötürücü', 'new_currency',
#        'real_price', 'type', 'door', 'State', 'Colored', 'year', 'horse_power',
#        'eng_type'],
#       dtype='object')

# %%
df['Qəzalı'].unique()
# Out:
# array(['Xeyr', 'Bəli'], dtype=object)

# %%
df.drop(columns = ['State'], inplace = True)

# %%
df['Hansı bazar üçün yığılıb'].isna().sum()
# Out:
# 189505

# %%
df['Sürətlər qutusu']
# Out:
# 0         Mexaniki
# 1         Mexaniki
# 2          Avtomat
# 3          Avtomat
# 4         Variator
#             ...
# 653716    Variator
# 653717    Mexaniki
# 653718     Avtomat
# 653719     Avtomat
# 653720     Avtomat
# Name: Sürətlər qutusu, Length: 653721, dtype: object

# %%
df
# Out:
#         engine_displacement_num  kilometrage_num            barter loan  \
# 0                           1.6           270000               NaN  NaN
# 1                           1.7                0               NaN  NaN
# 2                           4.0           164750               NaN  NaN
# 3                           2.0           126000               NaN  NaN
# 4                           1.5           354000               NaN  NaN
# ...                         ...              ...               ...  ...
# 653716                      1.5           320000  Barter mümkündür  NaN
# 653717                      2.9           155000               NaN  NaN
# 653718                      2.0            77926               NaN  NaN
# 653719                      4.7           250000  Barter mümkündür  NaN
# 653720                      3.0            19000  Barter mümkündür  NaN
#
#         salon Hansı bazar üçün yığılıb       Marka           Model Qəzalı  \
# ...

# %%
df.columns
# Out:
# Index(['engine_displacement_num', 'kilometrage_num', 'barter', 'loan', 'salon',
#        'Hansı bazar üçün yığılıb', 'Marka', 'Model', 'Qəzalı', 'Rəng',
#        'Sürətlər qutusu', 'Yeni', 'Yerlərin sayı', 'Ötürücü', 'new_currency',
#        'real_price', 'type', 'door', 'Colored', 'year', 'horse_power',
#        'eng_type'],
#       dtype='object')

# %%
df[['Marka', 'Model']]
# Out:
#              Marka           Model
# 0          Hyundai             i30
# 1       LADA (VAZ)     Niva Travel
# 2           Toyota    Land Cruiser
# 3          Hyundai         Elantra
# 4           Toyota           Prius
# ...            ...             ...
# 653716      Toyota           Prius
# 653717         UAZ          Hunter
# 653718     Hyundai         Elantra
# 653719        Jeep  Grand Cherokee
# 653720  Land Rover        Defender
#
# [653721 rows x 2 columns]

# %%
df.groupby(['horse_power'])['horse_power'].count()
# Out:
# horse_power
#  1 a.g.           1
#  10 a.g.         15
#  100 a.g.      1012
#  1000 a.g.        1
#  101 a.g.       653
#                ...
# 966 a.g.          1
# 97 a.g.        1536
# 98 a.g.        6716
# 99 a.g.        1945
# 992 a.g.          1
# Name: horse_power, Length: 1053, dtype: int64

# %%
df['Marka'].value_counts()
# Out:
# Marka
# Mercedes      90830
# Hyundai       85968
# Toyota        75167
# Kia           67029
# BMW           54432
#               ...
# Shuanghuan        1
# Sport             1
# Megelli           1
# Kayo              1
# Ural              1
# Name: count, Length: 208, dtype: int64

# %%
values = df['Ötürücü'].value_counts()

# %%
import matplotlib.pyplot as plt
plt.bar(values.index, height = values.values)
# Out:
# <BarContainer object of 3 artists>

# %%
count = df['year'].value_counts()
count
# Out:
# year
# 2024    73340
# 2015    55095
# 2014    46583
# 2016    40182
# 2017    33782
#         ...
# 1955        2
# 1938        2
# 1959        1
# 1947        1
# 1958        1
# Name: count, Length: 72, dtype: int64

# %%
import numpy as np
import pandas as pd

# %%
veziyyet_price = df.groupby(['Qəzalı'])['real_price'].mean()

# %%
plt.figure(figsize = (20,14))
plt.bar(veziyyet_price.index, veziyyet_price.values)
# Out:
# <BarContainer object of 2 artists>

# %%
df.groupby(['Colored'])['real_price'].mean()
# Out:
# Colored
# rənglənib       22259.209951
# rənglənməyib    42909.573590
# Name: real_price, dtype: float64

# %%
plt.figure(figsize = (10,7))
plt.scatter(df['year'], df['real_price'])

# %%
avg_prices = df.groupby(['Ötürücü'])['real_price'].mean()
avg_prices
# Out:
# Ötürücü
# Arxa    32778.399395
# Tam     74995.962607
# Ön      26431.730496
# Name: real_price, dtype: float64

# %%
plt.bar(avg_prices.index, avg_prices.values);

# %%
avg_price_per_brand = df.groupby(['Marka'])['real_price'].mean()

# %%
plt.figure (figsize = (20,14))
plt.scatter(avg_price_per_brand.index, avg_price_per_brand.values);
plt.xticks(rotation=90);

# %%
df.groupby(['Yeni'])['real_price'].mean()
# Out:
# Yeni
# Bəli    78232.063542
# Xeyr    36082.609426
# Name: real_price, dtype: float64

# %%
price_per_sq = df.groupby(['Sürətlər qutusu'])['real_price'].mean()

# %%
df['Sürətlər qutusu']
# Out:
# 0         Mexaniki
# 1         Mexaniki
# 2          Avtomat
# 3          Avtomat
# 4         Variator
#             ...
# 653716    Variator
# 653717    Mexaniki
# 653718     Avtomat
# 653719     Avtomat
# 653720     Avtomat
# Name: Sürətlər qutusu, Length: 653721, dtype: object

# %%
plt.bar(price_per_sq.index, price_per_sq.values);

# %%
door_graph = df.groupby(['door'])['real_price'].mean()

# %%
plt.figure(figsize = (10,7))
plt.bar(door_graph.index, door_graph.values);

# %%
df
# Out:
#         engine_displacement_num  kilometrage_num            barter loan  \
# 0                           1.6           270000               NaN  NaN
# 1                           1.7                0               NaN  NaN
# 2                           4.0           164750               NaN  NaN
# 3                           2.0           126000               NaN  NaN
# 4                           1.5           354000               NaN  NaN
# ...                         ...              ...               ...  ...
# 653716                      1.5           320000  Barter mümkündür  NaN
# 653717                      2.9           155000               NaN  NaN
# 653718                      2.0            77926               NaN  NaN
# 653719                      4.7           250000  Barter mümkündür  NaN
# 653720                      3.0            19000  Barter mümkündür  NaN
#
#         salon Hansı bazar üçün yığılıb       Marka           Model Qəzalı  \
# ...

# %%
df.columns
# Out:
# Index(['engine_displacement_num', 'kilometrage_num', 'barter', 'loan', 'salon',
#        'Hansı bazar üçün yığılıb', 'Marka', 'Model', 'Qəzalı', 'Rəng',
#        'Sürətlər qutusu', 'Yeni', 'Yerlərin sayı', 'Ötürücü', 'new_currency',
#        'real_price', 'type', 'door', 'Colored', 'year', 'horse_power',
#        'eng_type'],
#       dtype='object')

# %%
df['barter'] = df['barter'].fillna('Barter Mümkün deyil')

# %%
df['loan'] = df['loan'].fillna('Kreditdə deyil')

# %%
df['salon'].isna().sum()
# Out:
# 460382

# %%
df['salon']=df['salon'].fillna('no salon')

# %%
df['salon'].value_counts()
# Out:
# salon
# no salon    460382
# Salon       193339
# Name: count, dtype: int64

# %%
df['door'].tail(10)
# Out:
# 653711     5 qapı
# 653712       None
# 653713     5 qapı
# 653714       None
# 653715       None
# 653716       None
# 653717     5 qapı
# 653718       None
# 653719     5 qapı
# 653720     5 qapı
# Name: door, dtype: object

# %%
df['door'].value_counts()
# Out:
# door
# 5 qapı             286457
# 3 qapı               7404
# ikiqat kabin         4785
# 4 qapı                436
# açıq                  190
# tək kabin              54
# bir yarım kabin        29
# Name: count, dtype: int64

# %%
df['door'].unique()
# Out:
# array([' 5 qapı', None, ' 3 qapı', ' ikiqat kabin', ' 4 qapı', ' açıq',
#        ' tək kabin', ' bir yarım kabin'], dtype=object)

# %%
df['horse_power']=df['horse_power'].str.extract(r'(\d+)')

# %%
df['horse_power']
# Out:
# 0         115
# 1          80
# 2         282
# 3         150
# 4          76
#          ...
# 653716     76
# 653717    135
# 653718    150
# 653719    258
# 653720    400
# Name: horse_power, Length: 653721, dtype: object

# %%
df
# Out:
#         engine_displacement_num  kilometrage_num               barter  \
# 0                           1.6           270000  Barter Mümkün deyil
# 1                           1.7                0  Barter Mümkün deyil
# 2                           4.0           164750  Barter Mümkün deyil
# 3                           2.0           126000  Barter Mümkün deyil
# 4                           1.5           354000  Barter Mümkün deyil
# ...                         ...              ...                  ...
# 653716                      1.5           320000     Barter mümkündür
# 653717                      2.9           155000  Barter Mümkün deyil
# 653718                      2.0            77926  Barter Mümkün deyil
# 653719                      4.7           250000     Barter mümkündür
# 653720                      3.0            19000     Barter mümkündür
#
#                   loan     salon Hansı bazar üçün yığılıb       Marka  \
# ...

# %%
df.columns
# Out:
# Index(['engine_displacement_num', 'kilometrage_num', 'barter', 'loan', 'salon',
#        'Hansı bazar üçün yığılıb', 'Marka', 'Model', 'Qəzalı', 'Rəng',
#        'Sürətlər qutusu', 'Yeni', 'Yerlərin sayı', 'Ötürücü', 'new_currency',
#        'real_price', 'type', 'door', 'Colored', 'year', 'horse_power',
#        'eng_type'],
#       dtype='object')

# %%
df['Yeni'].isna().sum()
# Out:
# 0

# %%
df.drop(columns = ['new_currency'], inplace = True)

# %%
df
# Out:
#         engine_displacement_num  kilometrage_num               barter  \
# 0                           1.6           270000  Barter Mümkün deyil
# 1                           1.7                0  Barter Mümkün deyil
# 2                           4.0           164750  Barter Mümkün deyil
# 3                           2.0           126000  Barter Mümkün deyil
# 4                           1.5           354000  Barter Mümkün deyil
# ...                         ...              ...                  ...
# 653716                      1.5           320000     Barter mümkündür
# 653717                      2.9           155000  Barter Mümkün deyil
# 653718                      2.0            77926  Barter Mümkün deyil
# 653719                      4.7           250000     Barter mümkündür
# 653720                      3.0            19000     Barter mümkündür
#
#                   loan     salon Hansı bazar üçün yığılıb       Marka  \
# ...

# %%
df['door'].unique()
# Out:
# array([' 5 qapı', None, ' 3 qapı', ' ikiqat kabin', ' 4 qapı', ' açıq',
#        ' tək kabin', ' bir yarım kabin'], dtype=object)

# %%
df['engine_displacement_num'].dtype
# Out:
# dtype('float64')

# %%
df['kilometrage_num'].dtype
# Out:
# dtype('int64')

# %%
doors = df.groupby(['door'])['real_price'].mean()

# %%
plt.figure(figsize = (10,7))
plt.bar(doors.index, doors.values)
# Out:
# <BarContainer object of 7 artists>

# %%
df.shape
# Out:
# (653721, 21)

# %%
df['Sürətlər qutusu']
# Out:
# 0         Mexaniki
# 1         Mexaniki
# 2          Avtomat
# 3          Avtomat
# 4         Variator
#             ...
# 653716    Variator
# 653717    Mexaniki
# 653718     Avtomat
# 653719     Avtomat
# 653720     Avtomat
# Name: Sürətlər qutusu, Length: 653721, dtype: object

# %%
df.columns
# Out:
# Index(['engine_displacement_num', 'kilometrage_num', 'barter', 'loan', 'salon',
#        'Hansı bazar üçün yığılıb', 'Marka', 'Model', 'Qəzalı', 'Rəng',
#        'Sürətlər qutusu', 'Yeni', 'Yerlərin sayı', 'Ötürücü', 'real_price',
#        'type', 'door', 'Colored', 'year', 'horse_power', 'eng_type'],
#       dtype='object')

# %%
df['Yerlərin sayı'].dtype
# Out:
# dtype('O')

# %%
df['Yerlərin sayı']
# Out:
# 0           5
# 1           5
# 2          8+
# 3         NaN
# 4           5
#          ...
# 653716      5
# 653717    NaN
# 653718      5
# 653719      5
# 653720      5
# Name: Yerlərin sayı, Length: 653721, dtype: object

# %%
df['Yerlərin sayı'] = df['Yerlərin sayı'].str.extract(r'(\d+)')

# %%
df['Yerlərin sayı'] = pd.to_numeric(df['Yerlərin sayı'])

# %%
df['Yerlərin sayı'].isna().sum()
# Out:
# 165831

# %%
df['year'] = pd.to_numeric(df['year'] )

# %%
df['horse_power'] = pd.to_numeric(df['horse_power'])

# %%
df['kilometrage_num'].dtype
# Out:
# dtype('int64')

# %%
X = df.drop(columns = ['real_price'])

# %%
X
# Out:
#         engine_displacement_num  kilometrage_num               barter  \
# 0                           1.6           270000  Barter Mümkün deyil
# 1                           1.7                0  Barter Mümkün deyil
# 2                           4.0           164750  Barter Mümkün deyil
# 3                           2.0           126000  Barter Mümkün deyil
# 4                           1.5           354000  Barter Mümkün deyil
# ...                         ...              ...                  ...
# 653716                      1.5           320000     Barter mümkündür
# 653717                      2.9           155000  Barter Mümkün deyil
# 653718                      2.0            77926  Barter Mümkün deyil
# 653719                      4.7           250000     Barter mümkündür
# 653720                      3.0            19000     Barter mümkündür
#
#                   loan     salon Hansı bazar üçün yığılıb       Marka  \
# ...

# %%
y = df['real_price']

# %%
y
# Out:
# 0          15000.0
# 1          23700.0
# 2          60520.0
# 3          26700.0
# 4          10500.0
#             ...
# 653716     10800.0
# 653717      9500.0
# 653718     25400.0
# 653719     10600.0
# 653720    218450.0
# Name: real_price, Length: 653721, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.impute import SimpleImputer

# %%
X_train_full, X_test, y_train_full, y_test = train_test_split(X,y, test_size = 0.2)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, test_size = 0.2)

# %%
num_features = X_train.select_dtypes(include = [np.number]).columns
cat_features = X_train.select_dtypes(exclude = [np.number]).columns

# %%
num_features
# Out:
# Index(['engine_displacement_num', 'kilometrage_num', 'Yerlərin sayı', 'year',
#        'horse_power'],
#       dtype='object')

# %%
for col in df.select_dtypes(include = [np.number]).columns:
    df[col] = df[col].astype(np.float32)

# %%
df['year'].dtype
# Out:
# dtype('float32')

# %%
from lightgbm import LGBMRegressor

# %%
num_pipeline = Pipeline ([
    ('imputer', SimpleImputer(strategy = 'median')),
    ('scaler', StandardScaler())

])

cat_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy = 'most_frequent')),
    ('onehot', OneHotEncoder(sparse_output = True, handle_unknown = 'ignore'))
])
transformer = ColumnTransformer([
    ('num',num_pipeline, num_features),
    ('cat',cat_pipeline, cat_features)
], remainder = 'passthrough')

lgbm = LGBMRegressor(max_depth = 5, random_state = 42)

full_pipeline = Pipeline ([
    ('transformer', transformer),
    ('lgbm', lgbm)
])

# %%
full_pipeline.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.107675 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3277
# [LightGBM] [Info] Number of data points in the train set: 418380, number of used features: 1315
# [LightGBM] [Info] Start training from score 41780.394119
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
full_pipeline.score(X_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 0.951266256291252

# %%
full_pipeline.score(X_valid, y_valid)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 0.9487750695311232

# %%
full_pipeline.score(X_test, y_test)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 0.9515711800056462
