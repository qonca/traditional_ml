# %% [markdown]
# <a href="https://colab.research.google.com/github/qonca/traditional_ml/blob/main/Terrorist_homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub


path = kagglehub.dataset_download("START-UMD/gtd")

print("Path to dataset files:", path)
# Out:
# ...
# Path to dataset files: /root/.cache/kagglehub/datasets/START-UMD/gtd/versions/3

# %%
# !kaggle datasets download START-UMD/gtd
# Out:
# Dataset URL: https://www.kaggle.com/datasets/START-UMD/gtd
# License(s): other
# ...
#  45% 13.0M/28.7M [00:00<00:00, 135MB/s]
# 100% 28.7M/28.7M [00:00<00:00, 183MB/s]

# %%
# !unzip /content/gtd.zip
# Out:
# Archive:  /content/gtd.zip
# replace globalterrorismdb_0718dist.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import pandas as pd
df= pd.read_csv('/content/globalterrorismdb_0718dist.csv', encoding = 'latin-1')
# Out:
# <ipython-input-4-4c866762d4e5>:2: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv('/content/globalterrorismdb_0718dist.csv', encoding = 'latin-1')

# %%
df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
df.groupby(['iyear'])['nkill'].count().plot(kind='bar', figsize=(10,7));

# %%
year = df[df['iyear']==2016]
year
# Out:
#              eventid  iyear  imonth  iday           approxdate  extended  \
# 157202  201601010003   2016       1     1  2016-01-01 00:00:00         0
# 157203  201601010004   2016       1     1                  NaN         0
# 157204  201601010005   2016       1     1  2016-01-01 00:00:00         0
# 157205  201601010008   2016       1     1                  NaN         0
# 157206  201601010009   2016       1     1                  NaN         0
# ...              ...    ...     ...   ...                  ...       ...
# 170790  201612310040   2016      12    31                  NaN         0
# 170791  201612310042   2016      12    31                  NaN         0
# 170792  201612310043   2016      12    31                  NaN         1
# 170793  201612310044   2016      12    31                  NaN         0
# 171507  201701270001   2016      12    30                  NaN         0
#
#        resolution  country                       country_txt  region  ...  \
# ...

# %%
year.groupby(['region_txt'])['nkill'].count().sort_values().plot(kind='bar', figsize=(10,7));

# %%
import pandas as pd

# %%
months = df.groupby(['imonth'])['eventid'].count().reset_index()

# %%
months
# Out:
#     imonth  eventid
# 0        0       20
# 1        1    14936
# 2        2    13879
# 3        3    15257
# 4        4    15152
# 5        5    16875
# 6        6    15359
# 7        7    16268
# 8        8    15800
# 9        9    14180
# 10      10    15563
# 11      11    14906
# 12      12    13496

# %%
df.groupby(['imonth'])['eventid'].count().plot(kind = 'bar')
# Out:
# <Axes: xlabel='imonth'>

# %%
df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
df.groupby(df['iyear'])['attacktype1_txt'].count().plot(kind = 'bar')
# Out:
# <Axes: xlabel='iyear'>

# %%
a = df.groupby(['iyear','attacktype1_txt'])['nkill'].sum().reset_index()
a
# Out:
#      iyear                      attacktype1_txt   nkill
# 0     1970                        Armed Assault    36.0
# 1     1970                        Assassination    18.0
# 2     1970                    Bombing/Explosion    96.0
# 3     1970       Facility/Infrastructure Attack     9.0
# 4     1970                            Hijacking     1.0
# ..     ...                                  ...     ...
# 411   2017                            Hijacking    22.0
# 412   2017  Hostage Taking (Barricade Incident)   814.0
# 413   2017          Hostage Taking (Kidnapping)  2123.0
# 414   2017                      Unarmed Assault    78.0
# 415   2017                              Unknown  3852.0
#
# [416 rows x 3 columns]

# %%
a.loc[a.groupby('iyear')['nkill'].idxmax()]
# Out:
#      iyear                 attacktype1_txt    nkill
# 2     1970               Bombing/Explosion     96.0
# 11    1971               Bombing/Explosion     79.0
# 19    1972               Bombing/Explosion    281.0
# 26    1973                   Assassination    171.0
# 36    1974               Bombing/Explosion    286.0
# 43    1975                   Armed Assault    225.0
# 52    1976                   Assassination    233.0
# 60    1977                   Armed Assault    141.0
# 71    1978  Facility/Infrastructure Attack    434.0
# 76    1979                   Armed Assault    599.0
# 85    1980                   Armed Assault   2524.0
# 94    1981                   Armed Assault   2946.0
# 103   1982                   Armed Assault   3374.0
# 112   1983                   Armed Assault   6902.0
# 121   1984                   Armed Assault   6599.0
# 130   1985                   Armed Assault   4093.0
# 139   1986                   Armed Assault   1920.0
# ...

# %%
df.groupby(['region_txt'])['nkill'].max().reset_index()
# Out:
#                      region_txt   nkill
# 0         Australasia & Oceania    17.0
# 1   Central America & Caribbean   300.0
# 2                  Central Asia    50.0
# 3                     East Asia   184.0
# 4                Eastern Europe   344.0
# 5    Middle East & North Africa  1570.0
# 6                 North America  1384.0
# 7                 South America   275.0
# 8                    South Asia   518.0
# 9                Southeast Asia   116.0
# 10           Sub-Saharan Africa  1180.0
# 11               Western Europe   270.0

# %%
import matplotlib.pyplot as plt

# %%
df.plot(kind = 'scatter', x = 'longitude', y = 'latitude',c ='nkill', figsize = (12, 7),
        grid = True, alpha = 0.3, cmap = 'jet', s = df['nkill']/3);
plt.axis([-150, 180, -50, 70]);

# %%
df.groupby('targtype1_txt')['nkill'].sum().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='targtype1_txt'>

# %%
df.head(300).groupby(['gname', 'region_txt'])['nkill'].max().sort_values().plot(kind = 'bar', figsize = (10, 7));

# %%
df.groupby(['attacktype1_txt'])['eventid'].count().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='attacktype1_txt'>

# %%
b = df.groupby(['iyear', 'weaptype1_txt'])['eventid'].count().reset_index()
b
# Out:
#      iyear                                      weaptype1_txt  eventid
# 0     1970                                           Chemical        3
# 1     1970                                         Explosives      338
# 2     1970                                           Firearms       81
# 3     1970                                         Incendiary      176
# 4     1970                                              Melee        2
# ..     ...                                                ...      ...
# 395   2017                                              Melee      307
# 396   2017                                              Other       10
# 397   2017                                 Sabotage Equipment       11
# 398   2017                                            Unknown     1254
# 399   2017  Vehicle (not to include vehicle-borne explosiv...       23
#
# [400 rows x 3 columns]

# %%
b.loc[b.groupby('iyear')['eventid'].idxmax()]
# Out:
#      iyear weaptype1_txt  eventid
# 1     1970    Explosives      338
# 9     1971    Explosives      246
# 14    1972    Explosives      271
# 22    1973      Firearms      204
# 27    1974    Explosives      296
# 35    1975    Explosives      376
# 41    1976    Explosives      415
# 48    1977    Explosives      640
# 54    1978    Explosives      657
# 61    1979    Explosives     1091
# 74    1980      Firearms     1133
# 80    1981    Explosives     1068
# 86    1982    Explosives     1114
# 93    1983    Explosives     1230
# 100   1984    Explosives     1677
# 109   1985    Explosives     1478
# 117   1986    Explosives     1464
# 125   1987    Explosives     1431
# 134   1988      Firearms     1705
# 144   1989      Firearms     1947
# 153   1990    Explosives     1783
# 162   1991    Explosives     2033
# 172   1992      Firearms     2146
# 182   1994      Firearms     1287
# 191   1995      Firearms     1103
# 197   1996    Explosives     1235
# ...

# %%
c = df.head(1000).groupby(['gname','motive'])['eventid'].count().reset_index()

c.loc[c.groupby('gname')['eventid'].idxmax()]
# Out:
#                                                  gname  \
# 1                        Armed Commandos of Liberation
# 4     Armed Revolutionary Independence Movement (MIRA)
# 5                         Black Afro Militant Movement
# 8                                Black Liberation Army
# 26                                  Black Nationalists
# 43                                      Black Panthers
# 50                            Chicano Liberation Front
# 51                                    Chicano Radicals
# 53                                        Cuban Exiles
# 54                         Jewish Defense League (JDL)
# 57                                        Ku Klux Klan
# 62                                 Left-Wing Militants
# 103                                Neo-Nazi extremists
# 105                                    New Year's Gang
# 107                          Puerto Rican Nationalists
# 111                   Puerto Rican Resistance Movement
# ...
